# %% [markdown]
# # Potential plots etc, for irene monitor

# %%
import os
import sys
import tables as tb
import numpy  as np
from matplotlib import pyplot as plt
from glob import glob

from invisible_cities.cities.irene      import Irene
from invisible_cities.cities.irene_test import unpack_s12params, s12params
#from invisible_cities.reco.params   import S12Params as S12P, PMaps, Peak
from invisible_cities.types.ic_types_c import minmax
from invisible_cities.core.system_of_units_c import units
from invisible_cities.core.configure         import configure
from invisible_cities.reco import peak_functions_c as cpf
from invisible_cities.reco import peak_functions   as  pf
from invisible_cities.io   import pmap_io          as pio
from invisible_cities.evm .pmaps import S1, S2, S2Si, Peak
sys.path.append('/Users/alej/Desktop/Valencia/nextic/ICARO')
import icaro.marco_polo.monitor_functions as mf

montecarlo = True

# %%
ic_data = os.path.join(os.environ['IC_DATA'])

# MONTECARLO
if montecarlo:
    run = 0
    conf_path = '/Users/alej/Desktop/Valencia/nextic/IC-1/invisible_cities/config/irene.conf'
    PATH_IN  = ic_data + 'Montecarlo/Kr/new_mc/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_RWF_1000.root.h5'
    PATH_OUT  = ic_data + 'Montecarlo/Kr/new_mc/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_pmaps_1000.root.h5.h5'
    pmap_path = ic_data + '/LSC/pmaps/4446/pmaps.gdcsnext.1840_4446.root.h5'
    pmap_path = PATH_OUT
    rwf_path = PATH_IN

# Kr
else:
    run = 4446
    rwf_path  = ic_data + 'LSC/wvfms/4446/dst_waves.gdcsnext.*.root.h5'
    conf_path = '/Users/alej/Desktop/irene/irene.conf'
    PATH_OUT  = '/Users/alej/Desktop/irene/full_chain/Kr_4446_full_chain.h5'
    pmap_path = PATH_OUT

# %%
# initialize irene
#PATH_IN  = os.path.join(rwf_path)
PATH_OUT = os.path.join(PATH_OUT)
conf     = configure(('dummy ' + conf_path).split()).as_dict
if montecarlo:
    conf.update(dict(run_number = run,
                 files_in   = PATH_IN,
                 file_out   = PATH_OUT,
                 nmax       = 1000,
                 **unpack_s12params(s12params())))
else:
    conf.update(dict(run_number = run,
                 files_in   = PATH_IN,
                 file_out   = PATH_OUT,
                 nmax       = 100000))

irene = Irene(**conf)
irene.thr_sipm    =  2*units.pes
irene.thr_sipm_s2 = 15*units.pes
irene.run() # Turn on to generate new pmap_path
# Out:
#                  Irene will run a max of 1000 events
#                  Input Files = ['/Users/alej/Desktop/IC_DATA/Montecarlo/Kr/new_mc/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_RWF_1000.root.h5']
#                  Output File = /Users/alej/Desktop/IC_DATA/Montecarlo/Kr/new_mc/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_pmaps_1000.root.h5.h5
#
# ####################
# SensorParams
# ####################
# npmt: 12
# pmtwl: 48000
# nsipm: 1792
# sipmwl: 1200
#
#
#                  S1 parameters S12Params(time=minmax(min=99000.0, max=101000.0), stride=4, length=minmax(min=4, max=20), rebin=False)
#
#                  S2 parameters S12Params(time=minmax(min=101000.0, max=1199000.0), stride=40, length=minmax(min=80, max=200000), rebin=True)
#
#                  S2Si parameters
#                  threshold min charge per SiPM = 2.0 pes
#                  threshold min charge in  S2   = 15.0 pes
#
# Opening /Users/alej/Desktop/IC_DATA/Montecarlo/Kr/new_mc/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_RWF_1000.root.h5... event in file = 0, total = 0
# event in file = 1, total = 1
# event in file = 2, total = 2
# event in file = 3, total = 3
# event in file = 4, total = 4
# event in file = 5, total = 5
# event in file = 6, total = 6
# event in file = 7, total = 7
# event in file = 8, total = 8
# event in file = 9, total = 9
# event in file = 10, total = 10
# event in file = 11, total = 11
# event in file = 12, total = 12
# event in file = 13, total = 13
# event in file = 14, total = 14
# event in file = 15, total = 15
# event in file = 16, total = 16
# event in file = 17, total = 17
# event in file = 18, total = 18
# event in file = 19, total = 19
# event in file = 20, total = 20
# event in file = 21, total = 21
# event in file = 22, total = 22
# event in file = 23, total = 23
# event in file = 24, total = 24
# event in file = 25, total = 25
# event in file = 26, total = 26
# event in file = 27, total = 27
# event in file = 28, total = 28
# event in file = 29, total = 29
# event in file = 30, total = 30
# event in file = 31, total = 31
# event in file = 32, total = 32
# event in file = 33, total = 33
# event in file = 34, total = 34
# event in file = 35, total = 35
# event in file = 36, total = 36
# event in file = 37, total = 37
# event in file = 38, total = 38
# event in file = 39, total = 39
# event in file = 40, total = 40
# event in file = 41, total = 41
# event in file = 42, total = 42
# event in file = 43, total = 43
# event in file = 44, total = 44
# event in file = 45, total = 45
# event in file = 46, total = 46
# event in file = 47, total = 47
# event in file = 48, total = 48
# event in file = 49, total = 49
# event in file = 50, total = 50
# event in file = 51, total = 51
# event in file = 52, total = 52
# event in file = 53, total = 53
# event in file = 54, total = 54
# event in file = 55, total = 55
# event in file = 56, total = 56
# event in file = 57, total = 57
# event in file = 58, total = 58
# event in file = 59, total = 59
# event in file = 60, total = 60
# event in file = 61, total = 61
# event in file = 62, total = 62
# event in file = 63, total = 63
# event in file = 64, total = 64
# event in file = 65, total = 65
# event in file = 66, total = 66
# event in file = 67, total = 67
# event in file = 68, total = 68
# event in file = 69, total = 69
# event in file = 70, total = 70
# event in file = 71, total = 71
# event in file = 72, total = 72
# event in file = 73, total = 73
# event in file = 74, total = 74
# event in file = 75, total = 75
# event in file = 76, total = 76
# event in file = 77, total = 77
# event in file = 78, total = 78
# event in file = 79, total = 79
# event in file = 80, total = 80
# event in file = 81, total = 81
# event in file = 82, total = 82
# event in file = 83, total = 83
# event in file = 84, total = 84
# event in file = 85, total = 85
# event in file = 86, total = 86
# event in file = 87, total = 87
# event in file = 88, total = 88
# event in file = 89, total = 89
# event in file = 90, total = 90
# event in file = 91, total = 91
# event in file = 92, total = 92
# event in file = 93, total = 93
# event in file = 94, total = 94
# event in file = 95, total = 95
# event in file = 96, total = 96
# event in file = 97, total = 97
# event in file = 98, total = 98
# event in file = 99, total = 99
# event in file = 100, total = 100
# event in file = 101, total = 101
# event in file = 102, total = 102
# event in file = 103, total = 103
# event in file = 104, total = 104
# event in file = 105, total = 105
# event in file = 106, total = 106
# event in file = 107, total = 107
# event in file = 108, total = 108
# event in file = 109, total = 109
# event in file = 110, total = 110
# event in file = 111, total = 111
# event in file = 112, total = 112
# event in file = 113, total = 113
# event in file = 114, total = 114
# event in file = 115, total = 115
# event in file = 116, total = 116
# event in file = 117, total = 117
# event in file = 118, total = 118
# event in file = 119, total = 119
# event in file = 120, total = 120
# event in file = 121, total = 121
# event in file = 122, total = 122
# event in file = 123, total = 123
# event in file = 124, total = 124
# event in file = 125, total = 125
# event in file = 126, total = 126
# event in file = 127, total = 127
# event in file = 128, total = 128
# event in file = 129, total = 129
# event in file = 130, total = 130
# event in file = 131, total = 131
# event in file = 132, total = 132
# event in file = 133, total = 133
# event in file = 134, total = 134
# event in file = 135, total = 135
# event in file = 136, total = 136
# event in file = 137, total = 137
# event in file = 138, total = 138
# event in file = 139, total = 139
# event in file = 140, total = 140
# event in file = 141, total = 141
# event in file = 142, total = 142
# event in file = 143, total = 143
# event in file = 144, total = 144
# event in file = 145, total = 145
# event in file = 146, total = 146
# event in file = 147, total = 147
# event in file = 148, total = 148
# event in file = 149, total = 149
# event in file = 150, total = 150
# event in file = 151, total = 151
# event in file = 152, total = 152
# event in file = 153, total = 153
# event in file = 154, total = 154
# event in file = 155, total = 155
# event in file = 156, total = 156
# event in file = 157, total = 157
# event in file = 158, total = 158
# event in file = 159, total = 159
# event in file = 160, total = 160
# event in file = 161, total = 161
# event in file = 162, total = 162
# event in file = 163, total = 163
# event in file = 164, total = 164
# event in file = 165, total = 165
# event in file = 166, total = 166
# event in file = 167, total = 167
# event in file = 168, total = 168
# event in file = 169, total = 169
# event in file = 170, total = 170
# event in file = 171, total = 171
# event in file = 172, total = 172
# event in file = 173, total = 173
# event in file = 174, total = 174
# event in file = 175, total = 175
# event in file = 176, total = 176
# event in file = 177, total = 177
# event in file = 178, total = 178
# event in file = 179, total = 179
# event in file = 180, total = 180
# event in file = 181, total = 181
# event in file = 182, total = 182
# event in file = 183, total = 183
# event in file = 184, total = 184
# event in file = 185, total = 185
# event in file = 186, total = 186
# event in file = 187, total = 187
# event in file = 188, total = 188
# event in file = 189, total = 189
# event in file = 190, total = 190
# event in file = 191, total = 191
# event in file = 192, total = 192
# event in file = 193, total = 193
# event in file = 194, total = 194
# event in file = 195, total = 195
# event in file = 196, total = 196
# event in file = 197, total = 197
# event in file = 198, total = 198
# event in file = 199, total = 199
# event in file = 200, total = 200
# event in file = 201, total = 201
# event in file = 202, total = 202
# event in file = 203, total = 203
# event in file = 204, total = 204
# event in file = 205, total = 205
# event in file = 206, total = 206
# event in file = 207, total = 207
# event in file = 208, total = 208
# event in file = 209, total = 209
# event in file = 210, total = 210
# event in file = 211, total = 211
# event in file = 212, total = 212
# event in file = 213, total = 213
# event in file = 214, total = 214
# event in file = 215, total = 215
# event in file = 216, total = 216
# event in file = 217, total = 217
# event in file = 218, total = 218
# event in file = 219, total = 219
# event in file = 220, total = 220
# event in file = 221, total = 221
# event in file = 222, total = 222
# event in file = 223, total = 223
# event in file = 224, total = 224
# event in file = 225, total = 225
# event in file = 226, total = 226
# event in file = 227, total = 227
# event in file = 228, total = 228
# event in file = 229, total = 229
# event in file = 230, total = 230
# event in file = 231, total = 231
# event in file = 232, total = 232
# event in file = 233, total = 233
# event in file = 234, total = 234
# event in file = 235, total = 235
# event in file = 236, total = 236
# event in file = 482, total = 482
# event in file = 483, total = 483
# event in file = 484, total = 484
# event in file = 485, total = 485
# event in file = 486, total = 486
# event in file = 487, total = 487
# event in file = 488, total = 488
# event in file = 489, total = 489
# event in file = 490, total = 490
# event in file = 491, total = 491
# event in file = 492, total = 492
# event in file = 493, total = 493
# event in file = 494, total = 494
# event in file = 495, total = 495
# event in file = 496, total = 496
# event in file = 497, total = 497
# event in file = 498, total = 498
# event in file = 499, total = 499
# event in file = 500, total = 500
# event in file = 501, total = 501
# event in file = 502, total = 502
# event in file = 503, total = 503
# event in file = 504, total = 504
# event in file = 505, total = 505
# event in file = 506, total = 506
# event in file = 507, total = 507
# event in file = 508, total = 508
# event in file = 509, total = 509
# event in file = 510, total = 510
# event in file = 511, total = 511
# event in file = 512, total = 512
# event in file = 513, total = 513
# event in file = 514, total = 514
# event in file = 515, total = 515
# event in file = 516, total = 516
# event in file = 517, total = 517
# event in file = 518, total = 518
# event in file = 519, total = 519
# event in file = 520, total = 520
# event in file = 521, total = 521
# event in file = 522, total = 522
# event in file = 523, total = 523
# event in file = 524, total = 524
# event in file = 525, total = 525
# event in file = 526, total = 526
# event in file = 527, total = 527
# event in file = 528, total = 528
# event in file = 529, total = 529
# event in file = 530, total = 530
# event in file = 531, total = 531
# event in file = 532, total = 532
# event in file = 533, total = 533
# event in file = 534, total = 534
# event in file = 535, total = 535
# event in file = 536, total = 536
# event in file = 537, total = 537
# event in file = 538, total = 538
# event in file = 539, total = 539
# event in file = 540, total = 540
# event in file = 541, total = 541
# event in file = 542, total = 542
# event in file = 543, total = 543
# event in file = 544, total = 544
# event in file = 545, total = 545
# event in file = 546, total = 546
# event in file = 547, total = 547
# event in file = 548, total = 548
# event in file = 549, total = 549
# event in file = 550, total = 550
# event in file = 551, total = 551
# event in file = 552, total = 552
# event in file = 553, total = 553
# event in file = 554, total = 554
# event in file = 555, total = 555
# event in file = 556, total = 556
# event in file = 557, total = 557
# event in file = 558, total = 558
# event in file = 559, total = 559
# event in file = 560, total = 560
# event in file = 561, total = 561
# event in file = 562, total = 562
# event in file = 563, total = 563
# event in file = 564, total = 564
# event in file = 565, total = 565
# event in file = 566, total = 566
# event in file = 567, total = 567
# event in file = 568, total = 568
# event in file = 569, total = 569
# event in file = 570, total = 570
# event in file = 571, total = 571
# event in file = 572, total = 572
# event in file = 573, total = 573
# event in file = 574, total = 574
# event in file = 575, total = 575
# event in file = 576, total = 576
# event in file = 577, total = 577
# event in file = 578, total = 578
# event in file = 579, total = 579
# event in file = 580, total = 580
# event in file = 581, total = 581
# event in file = 582, total = 582
# event in file = 583, total = 583
# event in file = 584, total = 584
# event in file = 585, total = 585
# event in file = 586, total = 586
# event in file = 587, total = 587
# event in file = 588, total = 588
# event in file = 589, total = 589
# event in file = 590, total = 590
# event in file = 591, total = 591
# event in file = 592, total = 592
# event in file = 593, total = 593
# event in file = 594, total = 594
# event in file = 595, total = 595
# event in file = 596, total = 596
# event in file = 597, total = 597
# event in file = 598, total = 598
# event in file = 599, total = 599
# event in file = 600, total = 600
# event in file = 601, total = 601
# event in file = 602, total = 602
# event in file = 603, total = 603
# event in file = 604, total = 604
# event in file = 974, total = 974
# event in file = 975, total = 975
# event in file = 976, total = 976
# event in file = 977, total = 977
# event in file = 978, total = 978
# event in file = 979, total = 979
# event in file = 980, total = 980
# event in file = 981, total = 981
# event in file = 982, total = 982
# event in file = 983, total = 983
# event in file = 984, total = 984
# event in file = 985, total = 985
# event in file = 986, total = 986
# event in file = 987, total = 987
# event in file = 988, total = 988
# event in file = 989, total = 989
# event in file = 990, total = 990
# event in file = 991, total = 991
# event in file = 992, total = 992
# event in file = 993, total = 993
# event in file = 994, total = 994
# event in file = 995, total = 995
# event in file = 996, total = 996
# event in file = 997, total = 997
# event in file = 998, total = 998
# event in file = 999, total = 999
# irene: (counter = nmax, value = 1000),  (counter = n_events_tot, value = 1000),  (counter = n_empty_events, value = 0),

# %% [markdown]
# ## First, check that we have pmaps

# %%
with tb.open_file(rwf_path, 'r+') as f_rwfs:
    events = [f_rwfs.root.Run.events[i][0] for i in range(len(f_rwfs.root.Run.events[:]))]
nevts = len(events)
s1_dict, s2_dict, s2si_dict = pio.load_pmaps(pmap_path)

# %% [markdown]
# #### Ensure there are no empty s1d, s2d, s2sid

# %%
# Check to make sure no empty dictionaries (not sure if empty Si is allowed..)
for si_dict in [s1_dict, s2_dict, s2si_dict]:
    for si in si_dict.values():
        try: 
            for peak in si.s1d.values():
                assert len(peak) > 0
        except AttributeError:
            try:
                for peak in si.s2sid.values():
                    assert len(peak) > 0
            except AttributeError: 
                for peak in si.s2d.values():
                    assert len(peak) > 0

# %% [markdown]
# #### Look at the numbers of s1, s2, s2si

# %%
ns1 = 0; ns2 = 0; ns2si = 0
nbins = 10
s1_peaks   = []
s2_peaks   = []
s2si_peaks = []
for s1   in s1_dict  .values(): ns1   += len(s1.s1d)    ; s1_peaks  .append(len(s1  .s1d))
for s2   in s2_dict  .values(): ns2   += len(s2.s2d)    ; s2_peaks  .append(len(s2  .s2d))
for s2si in s2si_dict.values(): ns2si += len(s2si.s2sid); s2si_peaks.append(len(s2si.s2sid))
print('Number of events                               :', nevts)
print('Fract. of events with at least one s1, s2, s2si:', len(s1_dict  )/nevts, 
                                                          len(s2_dict  )/nevts, 
                                                          len(s2si_dict)/nevts)
print('Total S1, S2, s2si                             :', ns1,'',ns2,'',ns2si)

subplot=131
plt.figure(figsize=(15,5))
for si_peaks, title in zip([s1_peaks, s2_peaks, s2si_peaks], ['s1', 's2', 's2si']):
    si_peaks=np.array(si_peaks)
    plt.subplot(subplot)
    plt.hist(si_peaks, bins=range(nbins), align='left', normed=True)
    if si_peaks.max() > 1: plt.yscale('log')
    plt.xlim(0, si_peaks.max() + 1)
    if title == 's1': plt.xlim(0,10)
    plt.title(title + ' peaks per event (normed)')
    plt.grid(True)
    subplot+=1
plt.show()
# Out:
# Number of events                               : 1000
# Fract. of events with at least one s1, s2, s2si: 0.842 0.998 0.998
# Total S1, S2, s2si                             : 844  1001  1000

# %% [markdown]
# #### Housekeeping

# %%
# Get some csums
def calibrated_waveforms(events, irene, rwf_path, pmts=True, sipms=True):
    with tb.open_file(rwf_path ,'r') as f:
        CSUMs  = {}
        csipm  = {}
        for ev in events:
            if pmts : 
                CSUMs[ev] = irene.calibrated_pmt_sum(irene.deconv_pmt(f.root.RD.pmtrwf[ev]))[0]
                
                
            if sipms: csipm[ev] = irene.calibrated_signal_sipm(f.root.RD.sipmrwf[ev]).sum(axis=0)
    return CSUMs, csipm

# Plot some histograms for comparing positive and negative sections of wf
def compare_pos_neg_hist(arrs, titles, log=False, normed=False):
    plt.figure(figsize=(15,4))
    subplot=121
    for h, title in zip(arrs, titles):
        plt.subplot(subplot)
        plt.hist(h, normed=normed, bins=20)
        plt.grid(True)
        plt.title(title)
        if log: plt.yscale('log')
        plt.xlabel('pes')
        subplot+=1
    plt.show()

# %% [markdown]
# ## Study of csum waveforms

# %%
events   = mf.sample_events(-1, rwf_path, all_events=True)
i_events = events - events[0]
if montecarlo:
    events = list(range(100))
    i_events = events
CSUMs, _ = calibrated_waveforms(i_events, irene, rwf_path, sipms=False)

# %%
def compare_pos_neg_hist(arrs, titles, log=False, normed=False, xlabel='pes'):
    plt.figure(figsize=(15,4))
    subplot=121
    for h, title in zip(arrs, titles):
        plt.subplot(subplot)
        plt.hist(h, normed=normed, bins=20)
        plt.grid(True)
        plt.title(title)
        if log: plt.yscale('log')
        plt.xlabel(xlabel)
        subplot+=1
    plt.show()

# %% [markdown]
# #### Min and max values in csum

# %%
MIN = []
MAX = []
for fpmt in CSUMs.values():
    MIN.append(fpmt.min())
    MAX.append(fpmt.max())
compare_pos_neg_hist([MIN,MAX], ['Min value in wf', 'Max value in wf'], log=False)

# %% [markdown]
# #### Number of positive and negative entries in csum

# %%
POSen = []
NEGen = []
for fpmt in CSUMs.values():
    POSen.append(len(np.where(fpmt > 0)[0])) # n pos bins
    NEGen.append(len(np.where(fpmt < 0)[0])) # n neg bins
compare_pos_neg_hist([NEGen,POSen], 
                     ['Number of negative entries in wf', 
                      'Number of positive entries in wf'], 
                     log=False, xlabel='entries')

# %% [markdown]
# #### Sum of csum above and below 0

# %%
POS = []
NEG = []
for fpmt in CSUMs.values():
    POS.append(fpmt[np.where(fpmt > 0)[0]].sum()) # sum of all pos bins
    NEG.append(fpmt[np.where(fpmt < 0)[0]].sum()) # sum of all neg bins
compare_pos_neg_hist([NEG,POS], ['Cumululative negative wf', 'Cumulative positive wf'], log=False)

# %% [markdown]
# #### Mean positive and negative csum

# %%
POSn = []
NEGn = []
for fpmt in CSUMs.values():
    POSn.append(fpmt[np.where(fpmt > 0)[0]].sum() / len(np.where(fpmt > 0)[0])) # div by n pos bins
    NEGn.append(fpmt[np.where(fpmt < 0)[0]].sum() / len(np.where(fpmt < 0)[0])) #     by n neg bins
compare_pos_neg_hist([NEGn,POSn], ['Mean negative wf', 'Mean positive wf'], log=False)

# %% [markdown]
# Once we start saving the individual pmt S2s, we can make similar plots with those.

# %% [markdown]
# ## Check that the peaks of a random sample of individual events make sense

# %%
# Plot Peak and WF on top of each other
def plot_wf_vs_s12_peak(csum, peak,
                        subplot = -1, 
                        wfbs    = 25*units.ns,
                        pkbs    = 25*units.ns,
                        S12     = 'S1', 
                        plotwf  = plt.scatter, 
                        plotp   = plt.scatter,
                        pc      = 'r'):
    
    if subplot != -1: plt.subplot(subplot)
        
    # helpful since rebinning algorithm record average time 
    t = np.copy(peak.t)
    if S12=='S2Si': t-= 500  *units.ns # typically  1mus time bins 
        
    plotwf(np.arange(len(csum))*wfbs/units.mus, csum, label='wf', s=300, alpha=.3) # Plot wf
    plotp(t/units.mus, peak.E *wfbs/pkbs, label=S12, alpha=.5, c=pc)              # Plot peak
    plt.xlim((peak.t[0] - 2*pkbs) / units.mus, (t[-1] + 2*pkbs)/units.mus) # Set xlim around peak
    plt.ylim(0, peak.E.max()*wfbs/pkbs + .25*peak.E.max()*wfbs/pkbs)      # Set ylim around peak
    plt.legend()
    plt.grid(True)
    plt.ylabel('pes')
    plt.xlabel('time (microseconds)')

# %% [markdown]
# #### Get a small random sample of events
# Need calibrated sums of pmts and sipms

# %%
ev_sample = mf.sample_events(9, rwf_path)
i_ev = ev_sample - events[0]
CSUMs, csipm = calibrated_waveforms(i_ev, irene, rwf_path, sipms=True)

# %% [markdown]
# #### Some S1s
# These should be exact copies of the waveform since there is no rebinning

# %%
plt.figure(figsize=(15,15))
subplot=331
for i, ev in zip(i_ev, ev_sample):
    if ev in s1_dict:
        pn = np.array(list(s1_dict[ev].peaks.keys())).max() # choose 1 peak_no (here max)
        plot_wf_vs_s12_peak(CSUMs[i], s1_dict[ev].peaks[pn], subplot=subplot)
        subplot+=1
plt.show()

# %% [markdown]
# #### Some S2s
# There has been rebinning, so S2 should look like a best fit line to the wf.
# Note: s2 amplitudes have been multipled by (wf time bin size 25ns / s2 time bin size 1000ns) so that amplitudes match

# %%
plt.figure(figsize=(15,15))
subplot=331
for i, ev in zip(i_ev, ev_sample):
    if ev in s2_dict:
        pn = np.array(list(s2_dict[ev].peaks.keys())).max()
        plot_wf_vs_s12_peak(CSUMs[i], s2_dict[ev].peaks[pn], 
                            subplot=subplot, 
                            pkbs=units.mus, 
                            plotp=plt.plot,
                            S12='S2',
                            pc='r')    
    subplot+=1
plt.show()

# %% [markdown]
# #### Some S2Si
# The S2Si should look very similar to the wf. If S2Si threshold is set to zero, data points in the wf and S2Si should match perfectly. Since typically the threshold is quite high ~3.5pes, we cannot expect an exact match between the data points, typically the S2Si peak should be slightly smaller than the peak seen in the wf.
#
# Note: light arriving to the first SiPM time bin arrives on average at .5mus not at 0mus and `rebin_waveform` takes this into account by construction

# %%
subplot=331
plt.figure(figsize=(15,15))
for i, ev in zip(i_ev, ev_sample):
    if not ev in s2si_dict: continue
    s2si = s2si_dict[ev]
    pn = np.array(list(s2si.peaks.keys())).max()
    t = s2si.s2d[pn][0]
    s2si_sum = np.zeros_like(t)
    for sipm in s2si.s2sid[pn]: 
        s2si_sum += s2si.s2sid[pn][sipm]
    plot_wf_vs_s12_peak(np.array(csipm[i]), Peak(t, s2si_sum),
                        subplot=subplot,
                        wfbs=units.mus,
                        pkbs=units.mus,
                        plotp=plt.plot,
                        S12='S2Si',
                        pc='r')
    subplot+=1
plt.show()

# %% [markdown]
# ## Future monitor plots etc:
#
# 1) Whatever useful information we can get out of acum in sierpe (JJ talked about)
# 2) tons of the information contained in the kdst should probably also be used for monitoring; however i assume we want to keep this separate from the irene monitor / avoid writing code multiple times. (heat map, s12 properties, drift time etc)
